# %% [markdown]
# # Tree Data Structure
#
# ##### A tree is a heirarchical data structure with a Parent-to-child relationship. A tree is composed of **nodes**(which hold the data) and **edges**(which connects them with other nodes)
