# %% [markdown]
# # Stack
#
# A stack is an ordered collection of items where insertion and deletion of items occur on the same end.
#
# Elements are inserted an removed adhering to the LIFO (Last in First out)
#
# The **basic methods** of stacks are:
# - **Push**: Adds element to Stack
#
# - **Pop**: Removes element from Stack
# - **isEmpty**: Returns boolean based on if stack is Empty
# - **Peek**: Returns top element of Stack
# - **Size**: Returns number of items in Stack
#
# Here is a Stack's Implementation using **Nodes**:
#
# First we start with the building block (Node Class)

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

# %% [markdown]
# Now the actual Stack Class

# %%
class Stack:
    def __init__(self):
        self.top = None
    
    def push(self, value):
        new_node = Node(value)
        new_node.next = self.top
        self.top = new_node
        
    def pop(self):
        popped_node = self.top
        self.top = self.top.next
        
        return popped_node.value
    
    def isEmpty(self):
        return self.top is None
    
    def peek(self):
        return self.top.value
    
    def size(self):
        count = 0
        curr = self.top
        
        while curr is not None:
            count += 1
            curr = curr.next
        
        return count

# %% [markdown]
# ### *Application of Stacks*
#
# Stacks can be used to evaluate **Infix** & **Postfix** expressions.
#
# - **Infix**: Math written with the operator between the two operands. *Ex: (a + b)*
#
# - **Postfix**: Math written with the operator following the operands. *Ex: (a b +)*
#
# Let's try it below:
# A stack will help us solve a **Postfix** expression by,
#
# 1. `Pushing` encountered operands into the Stack
#
# 2. If we encounter an operation, we `pop()` and use the last two operands in the Stack
#
# 3. After doing some math, we push the result back into the Stack
#
# 4. We <u>repeat</u> this process until the Stack eventually has one item left.
#
# Note: This is possible because of how Postfix has order encoded, hence why parenthesis aren't required. <a href="https://www.geeksforgeeks.org/dsa/evaluation-of-postfix-expression/">Learn more here</a>

# %%
import operator
# This built-in library will allow us to make a dictionary of operators matching with their functioning

#Infix Version: 4 + (3 - 2) * 5
expression = "432-5*+"

operators = {
    '*': operator.mul, 
    '-': operator.sub, 
    "+": operator.add, 
    "/": operator.truediv
    }

myStack = Stack()

for item in expression:
    if item in operators:
        num2 = myStack.pop()
        num1 = myStack.pop()
        
        operator_func = operators[item] # This is why we used operators library
        result = operator_func(num1, num2)
        myStack.push(result)
    else:
        myStack.push(int(item))

print(myStack.top.value)
# We should get 9
# Out:
# 9

# %% [markdown]
# ---
# # Queue
#
# A queue is an ordered collection of items where additions and deletions occur on opposite ends.
#
# Elements are inserted an removed adhering to **FIFO** (First In, First Out) principle
#
#
# The **basic methods** of queues are:
# - **Enqueue**: Adds element to tail of queue
#
# - **Dequeue**: Removes element from head of queue
# - **isEmpty**: Returns boolean based on if queue is Empty
# - **Peek**: Returns head element of queue
# - **Size**: Returns number of items in queue
#
# Here is a Queue's Implementation using **Nodes**:

# %%
class Queue:
    def __init__(self):
        self.head = None
        self.tail = None
    
    def enqueue(self, value):
        new_node = Node(value)
        
        if self.isEmpty():
            self.head = new_node
            self.tail = new_node  
        else:
            self.tail.next = new_node
            self.tail = new_node
    
    def dequeue(self):
        self.head = self.head.next
    
    def isEmpty(self):
        return self.head is None
    
    def peek(self):
        return self.head.value
    
    def size(self):
        count = 0
        curr = self.head
        
        while curr:
            count += 1
            curr = curr.next
        
        return count

# %% [markdown]
# ## Deque?
#
# - A dequeue is a double-ended queue
# - Insertions & deletions occurs at either end
#
# Deques be implemented from scratch initialized using `collections.deque`

# %%
import collections

myDequeue = collections.deque()
