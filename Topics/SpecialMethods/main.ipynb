# %% [markdown]
# # Special Functions
#
# Special Functions are also known as "dunder methods" (double-underscore methods). They are identified through their unique prefix/suffix as shown: `__SpecialMethod__()`
#
# Some of the common ones include but are not limited to:
#
# - `__init__(self, ...)`
# - `__repr__`
# - `__str__`
# - `__len__`
