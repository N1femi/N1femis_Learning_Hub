# %% [markdown]
# # Memory Management
#
# This notebook will speak on the following topics:
#
# - Foundational Data Types
# - Memory Structure
# - Garbage Collector
#
# !["Ghost sorting through files"]("https://tenor.com/view/soul-terry-files-searching-gif-382326095464696158")
